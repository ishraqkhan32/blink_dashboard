# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options

# %%
CHROME_PATH = "/Users/ik/bin/chromedriver"

# %%
# initialize web driver with eager page loading strategy
chrome_options = Options()
chrome_options.page_load_strategy = 'eager'
driver = webdriver.Chrome(CHROME_PATH, options=chrome_options)

# %%
driver.get('https://locations.blinkfitness.com/index.html')

# %% [markdown]
# ## Crawl main index site for list of links to each state/regions branch directory

# %%
# get links to each region home page
driver.get('https://locations.blinkfitness.com/index.html')
links = WebDriverWait(driver, timeout=30).until(lambda d: d.find_elements_by_tag_name('a'))

location_urls = [] # will contain final urls
skip = ['index','search']

for link in links:
    # get all links on webpage
    url_string = link.get_attribute('href')
    
    # check for branch state sublinks only 
    if url_string.startswith('https://locations.blinkfitness.com/'):
        if not any(x in url_string for x in skip):
            branch_state = link.text 
            location_urls.append(url_string)

# will handle special case separately
location_urls.remove('https://locations.blinkfitness.com/va/virginia-beach/4239-holland-road')

# %% [markdown]
# ## Helper function: get status of each gym
# Possible statuses based on preliminary inspection
# * Open Now
# * Closed (for the day)
# * Coming Soon
# * Temporarily Closed (due to covid)
#
# Both are contained within the Teaser-info div but different elements depending on whether the branch is running (first two choices) vs if it's currently not in service (last two choices).
#
# I'll check for the div that should contain the status and if it does not exist, then I'll look for the div that states otherwise.

# %%
status_dict = {
    0: ['Temporarily Closed', 'Closed'], # branch not in service due to covid
    1: ['Coming Soon'], # branch not in service yet
    2: ['Open Now'], # branch in service and currently open <- target status
    3: ['Closed - Opens at'] # branch in service but currently closed
}

# function that finds status of individual directory listing
def find_status(branch):
    # if branch is open, status is contained in Hours-statusText element
    try:
        status = branch.find_element_by_class_name('Hours-statusText').text.strip()
    # else look for Teaser-text
    except:
        status = branch.find_element_by_class_name('Teaser-text').text
    
    # return status as integer value for efficient storage and comparison
    for k,v in status_dict.items():
        if status in v:
            return k
    return None

# %% [markdown]
# ## Parse individual branches from each region directory page

# %%
location_info = []

for region_url in location_urls:
    driver.get(region_url)
    
    # parse city containers
    cities = WebDriverWait(driver, timeout=30).until(lambda d: d.find_elements_by_class_name('Directory-cityContainer'))  
    
    for city in cities:
        branch_city = city.find_element_by_class_name('Directory-cityName').text
        
        # get list of all branches in city container
        branches = city.find_elements_by_class_name('Directory-listTeaser')
        
        # parse each branch for title, address & phone number
        for branch in branches:
            temp_branch = {}
            # temp_branch['branch_state'] = 
            temp_branch['branch_url'] = branch.find_element_by_class_name('Teaser-titleLink').get_attribute('href')
            temp_branch['branch_city'] = branch_city
            temp_branch['branch_title'] = branch.find_element_by_class_name('Teaser-title').text
            temp_branch['branch_address'] = branch.find_element_by_class_name('Teaser-address').text
            temp_branch['branch_phone'] = branch.find_element_by_class_name('Teaser-phone').text
            temp_branch['branch_status'] = find_status(branch)
            
            location_info.append(temp_branch)

# %% [markdown]
# ## Handle parsing of special case: Virginia Beach branch
# Virginia only has 1 location right now so it doesn't have a separate directory page like all other states

# %%
temp = {}
va_url = 'https://locations.blinkfitness.com/va/virginia-beach/4239-holland-road'

driver.get(va_url)
va_info = WebDriverWait(driver, timeout=30).until(lambda d: d.find_element_by_class_name('Core'))  

temp['url'] = va_url
temp['state'] = 'Virginia'
temp['city'] = 'Virginia Beach'
temp['title'] = va_info.find_element_by_class_name('LocationName-geo').text
temp['phone'] = va_info.find_element_by_id('phone-main').text
temp['address'] = va_info.find_element_by_class_name('c-address').text

location_info.append(temp)

# %%
from pprint import pprint
for i in location_info:
    pprint(i)
# Out:
# {'address': '2251 West Ball Road',
#  'city': 'Anaheim',
#  'phone': '(714) 790-3555',
#  'status': 0,
#  'title': 'Anaheim',
#  'url': 'https://locations.blinkfitness.com/ca/anaheim/2251-west-ball-road'}
# {'address': '16121 Bellflower Blvd.',
#  'city': 'Bellflower',
#  'phone': '(562) 725-7133',
#  'status': 0,
#  'title': 'Bellflower',
#  'url': 'https://locations.blinkfitness.com/ca/bellflower/16121-bellflower-blvd.'}
# {'address': '1060 West Alameda Avenue',
#  'city': 'Burbank',
#  'phone': '(818) 686-5930',
#  'status': 0,
#  'title': 'Burbank',
#  'url': 'https://locations.blinkfitness.com/ca/burbank/1060-west-alameda-avenue'}
# {'address': '15519 Normandie Avenue',
#  'city': 'Gardena',
#  'phone': '(424) 292-8150',
#  'status': 0,
#  'title': 'Gardena',
#  'url': 'https://locations.blinkfitness.com/ca/gardena/15519-normandie-avenue'}
# {'address': '6714 Pacific Boulevard',
#  'city': 'Huntington Park',
#  'phone': '(323) 538-8705',
#  'status': 0,
#  'title': 'Huntington Park',
#  'url': 'https://locations.blinkfitness.com/ca/huntington-park/6714-pacific-boulevard'}
# {'address': '2450 East Century Blvd',
#  'city': 'Los Angeles',
#  'phone': '(213) 279-8879',
#  'status': 0,
#  'title': 'Watts',
#  'url': 'https://locations.blinkfitness.com/ca/los-angeles/2450-east-century-blvd'}
# {'address': '130 West G Street',
#  'city': 'Ontario',
#  'phone': '(909) 757-7894',
#  'status': 0,
#  'title': 'Ontario',
#  'url': 'https://locations.blinkfitness.com/ca/ontario/130-west-g-street'}
# {'address': '1205-1299 W Foothill Blvd',
#  'city': 'Rialto',
#  'phone': '(909) 990-1266',
#  'status': 1,
#  'title': 'Rialto',
#  'url': 'https://locations.blinkfitness.com/ca/rialto/1205-1299-w-foothill-blvd'}
# {'address': '1102 Dunn Avenue',
#  'city': 'Jacksonville',
#  'phone': '(904) 512-1175',
#  'status': 3,
#  'title': 'Jacksonville',
#  'url': 'https://locations.blinkfitness.com/fl/jacksonville/1102-dunn-avenue'}
# {'address': '3352 South University Drive',
#  'city': 'Miramar',
#  'phone': '(754) 799-2002',
#  'status': 3,
#  'title': 'Miramar',
#  'url': 'https://locations.blinkfitness.com/fl/miramar/3352-south-university-drive'}
# {'address': '5160 South Pulaski Road',
#  'city': 'Chicago',
#  'phone': '(929) 435-4764',
#  'status': 3,
#  'title': 'Midway',
#  'url': 'https://locations.blinkfitness.com/il/chicago/5160-south-pulaski-road'}
# {'address': '3145 South Ashland Avenue',
#  'city': 'Chicago',
#  'phone': '(618) 202-2124',
#  'status': 3,
#  'title': 'Bridgeport',
#  'url': 'https://locations.blinkfitness.com/il/chicago/3145-south-ashland-avenue'}
# {'address': '1926 Demptser St',
#  'city': 'Evanston',
#  'phone': '(224) 296-0010',
#  'status': 3,
#  'title': 'Evanston',
#  'url': 'https://locations.blinkfitness.com/il/evanston/1926-demptser-st'}
# {'address': '3243 West 115th Street',
#  'city': 'Merrionette Park',
#  'phone': '(708) 972-1407',
#  'status': 3,
#  'title': 'Merrionette Park',
#  'url': 'https://locations.blinkfitness.com/il/merrionette-park/3243-west-115th-street'}
# {'address': '8749 S. Ridgeland Avenue',
#  'city': 'Oak Lawn',
#  'phone': '(224) 401-1459',
#  'status': 3,
#  'title': 'Oak Lawn',
#  'url': 'https://locations.blinkfitness.com/il/oak-lawn/8749-s.-ridgeland-avenue'}
# {'address': '7509 West Cermak Road',
#  'city': 'Riverside',
#  'phone': '(708) 443-1001',
#  'status': 0,
#  'title': 'North Riverside',
#  'url': 'https://locations.blinkfitness.com/il/riverside/7509-west-cermak-road'}
# {'address': '71 Dodge Street',
#  'city': 'Beverly',
#  'phone': '(978) 922-9100',
#  'status': 3,
#  'title': 'Beverly',
#  'url': 'https://locations.blinkfitness.com/ma/beverly/71-dodge-street'}
# {'address': '465 Salem Street',
#  'city': 'Medford',
#  'phone': '(781) 391-2100',
#  'status': 3,
#  'title': 'Medford',
#  'url': 'https://locations.blinkfitness.com/ma/medford/465-salem-street'}
# {'address': '9395 Telegraph Road',
#  'city': 'Redford',
#  'phone': '(313) 217-7830',
#  'status': 3,
#  'title': 'Redford',
#  'url': 'https://locations.blinkfitness.com/mi/redford/9395-telegraph-road'}
# {'address': '26475 Hoover Road',
#  'city': 'Warren',
#  'phone': '(586) 381-7058',
#  'status': 3,
#  'title': 'Warren',
#  'url': 'https://locations.blinkfitness.com/mi/warren/26475-hoover-road'}
# {'address': '1006 Route 46',
#  'city': 'Clifton',
#  'phone': '(973) 855-3254',
#  'status': 3,
#  'title': 'Clifton',
#  'url': 'https://locations.blinkfitness.com/nj/clifton/1006-route-46'}
# {'address': '600 Central Avenue',
#  'city': 'East Orange',
#  'phone': '(862) 444-2190',
#  'status': 3,
#  'title': 'East Orange',
#  'url': 'https://locations.blinkfitness.com/nj/east-orange/600-central-avenue'}
# {'address': '440 Eastern Parkway',
#  'city': 'Irvington',
#  'phone': '(862) 229-6744',
#  'status': 3,
#  'title': 'Irvington',
#  'url': 'https://locations.blinkfitness.com/nj/irvington/440-eastern-parkway'}
# {'address': '35 Journal Square',
#  'city': 'Jersey City',
#  'phone': '(201) 204-4360',
#  'status': 3,
#  'title': 'Journal Square',
#  'url': 'https://locations.blinkfitness.com/nj/jersey-city/35-journal-square'}
# {'address': '1701 West Edgar Road',
#  'city': 'Linden',
#  'phone': '(908) 583-8650',
#  'status': 3,
#  'title': 'Linden',
#  'url': 'https://locations.blinkfitness.com/nj/linden/1701-west-edgar-road'}
# {'address': '4 Memorial Drive',
#  'city': 'Lodi',
#  'phone': '(973) 855-3250',
#  'status': 3,
#  'title': 'Lodi',
#  'url': 'https://locations.blinkfitness.com/nj/lodi/4-memorial-drive'}
# {'address': '2-14 Ferry Street',
#  'city': 'Newark',
#  'phone': '(973) 564-1710',
#  'status': 0,
#  'title': 'Ironbound',
#  'url': 'https://locations.blinkfitness.com/nj/newark/2-14-ferry-street'}
# {'address': '364 Centre Street',
#  'city': 'Nutley',
#  'phone': '(973) 798-1490',
#  'status': 3,
#  'title': 'Nutley',
#  'url': 'https://locations.blinkfitness.com/nj/nutley/364-centre-street'}
# {'address': '151 Bergen Town Center',
#  'city': 'Paramus',
#  'phone': '(201) 845-5055',
#  'status': 3,
#  'title': 'Paramus',
#  'url': 'https://locations.blinkfitness.com/nj/paramus/151-bergen-town-center'}
# {'address': '3053 Route 46',
#  'city': 'Parsippany',
#  'phone': '(973) 532-6780',
#  'status': 3,
#  'title': 'Parsippany',
#  'url': 'https://locations.blinkfitness.com/nj/parsippany/3053-route-46'}
# {'address': '663 Main Avenue',
#  'city': 'Passaic',
#  'phone': '(973) 358-8020',
#  'status': 3,
#  'title': 'Passaic',
#  'url': 'https://locations.blinkfitness.com/nj/passaic/663-main-avenue'}
# {'address': '133 New Brunswick Avenue',
#  'city': 'Perth Amboy',
#  'phone': '(732) 243-8530',
#  'status': 3,
#  'title': 'Perth Amboy',
#  'url': 'https://locations.blinkfitness.com/nj/perth-amboy/133-new-brunswick-avenue'}
# {'address': '235-255 East Front Street',
#  'city': 'Plainfield',
#  'phone': '(908) 490-8130',
#  'status': 3,
#  'title': 'Plainfield',
#  'url': 'https://locations.blinkfitness.com/nj/plainfield/235-255-east-front-street'}
# {'address': '451 Valley Street',
#  'city': 'South Orange',
#  'phone': '(973) 564-1494',
#  'status': 3,
#  'title': 'South Orange',
#  'url': 'https://locations.blinkfitness.com/nj/south-orange/451-valley-street'}
# {'address': '2700 Route 22',
#  'city': 'Union',
#  'phone': '(973) 241-1115',
#  'status': 3,
#  'title': 'Union',
#  'url': 'https://locations.blinkfitness.com/nj/union/2700-route-22'}
# {'address': '498 Beverly Rancocas Road',
#  'city': 'Willingboro',
#  'phone': '(856) 394-4081',
#  'status': 3,
#  'title': 'Willingboro',
#  'url': 'https://locations.blinkfitness.com/nj/willingboro/498-beverly-rancocas-road'}
# {'address': '32-27 Steinway Street',
#  'city': 'Astoria',
#  'phone': '(718) 880-3616',
#  'status': 3,
#  'title': 'Astoria',
#  'url': 'https://locations.blinkfitness.com/ny/astoria/32-27-steinway-street'}
# {'address': '1789 Grand Avenue',
#  'city': 'Baldwin',
#  'phone': '(516) 453-6726',
#  'status': 3,
#  'title': 'Baldwin',
#  'url': 'https://locations.blinkfitness.com/ny/baldwin/1789-grand-avenue'}
# {'address': '480 Suffolk Avenue',
#  'city': 'Brentwood',
#  'phone': '(631) 352-2600',
#  'status': 3,
#  'title': 'Brentwood',
#  'url': 'https://locations.blinkfitness.com/ny/brentwood/480-suffolk-avenue'}
# {'address': '1380 Metropolitan Avenue',
#  'city': 'Bronx',
#  'phone': '(347) 640-5111',
#  'status': 3,
#  'title': 'Parkchester',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/1380-metropolitan-avenue'}
# {'address': "744 St. Ann's Avenue",
#  'city': 'Bronx',
#  'phone': '(917) 688-3030',
#  'status': 3,
#  'title': "St Ann's",
#  'url': 'https://locations.blinkfitness.com/ny/bronx/744-st.-anns-avenue'}
# {'address': '820 Concourse Village West',
#  'city': 'Bronx',
#  'phone': '(718) 704-1600',
#  'status': 3,
#  'title': 'Concourse Village',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/820-concourse-village-west'}
# {'address': '2374 Grand Concourse',
#  'city': 'Bronx',
#  'phone': '(646) 237-9100',
#  'status': 3,
#  'title': 'Fordham',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/2374-grand-concourse'}
# {'address': '3580 White Plains Road',
#  'city': 'Bronx',
#  'phone': '(347) 482-2825',
#  'status': 3,
#  'title': 'Gun Hill',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/3580-white-plains-road'}
# {'address': '1490 Macombs Road',
#  'city': 'Bronx',
#  'phone': '(718) 304-1207',
#  'status': 3,
#  'title': 'Mt. Eden',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/1490-macombs-road'}
# {'address': '5520 Broadway',
#  'city': 'Bronx',
#  'phone': '(347) 532-7700',
#  'status': 3,
#  'title': 'Riverdale',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/5520-broadway'}
# {'address': '570 Melrose Avenue',
#  'city': 'Bronx',
#  'phone': '(347) 338-6459',
#  'status': 3,
#  'title': 'In The Hub',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/570-melrose-avenue'}
# {'address': '932 Southern Boulevard',
#  'city': 'Bronx',
#  'phone': '(347) 532-7702',
#  'status': 3,
#  'title': 'Hunts Point',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/932-southern-boulevard'}
# {'address': '645 E. Tremont Avenue',
#  'city': 'Bronx',
#  'phone': '(917) 719-8810',
#  'status': 3,
#  'title': 'East Tremont',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/645-e.-tremont-avenue'}
# {'address': '1421 Webster Ave',
#  'city': 'Bronx',
#  'phone': '(929) 526-4230',
#  'status': 3,
#  'title': 'Claremont',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/1421-webster-ave'}
# {'address': '3000 Jerome Avenue',
#  'city': 'Bronx',
#  'phone': '(718) 362-8080',
#  'status': 3,
#  'title': 'Bedford Park',
#  'url': 'https://locations.blinkfitness.com/ny/bronx/3000-jerome-avenue'}
# {'address': '2166 Nostrand Avenue',
#  'city': 'Brooklyn',
#  'phone': '(347) 943-6700',
#  'status': 3,
#  'title': 'Junction',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/2166-nostrand-avenue'}
# {'address': '833 Flatbush Avenue',
#  'city': 'Brooklyn',
#  'phone': '(718) 704-1700',
#  'status': 3,
#  'title': 'Flatbush',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/833-flatbush-avenue'}
# {'address': '250 Utica Avenue',
#  'city': 'Brooklyn',
#  'phone': '(718) 844-5335',
#  'status': 3,
#  'title': 'Crown Heights',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/250-utica-avenue'}
# {'address': '3779 Nostrand Avenue',
#  'city': 'Brooklyn',
#  'phone': '(646) 795-2960',
#  'status': 3,
#  'title': 'Sheepshead Bay',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/3779-nostrand-avenue'}
# {'address': '1002 Gates Avenue',
#  'city': 'Brooklyn',
#  'phone': '(718) 304-1205',
#  'status': 3,
#  'title': 'Gates',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/1002-gates-avenue'}
# {'address': '1413 Fulton Street',
#  'city': 'Brooklyn',
#  'phone': '(347) 991-8707',
#  'status': 3,
#  'title': 'Bed-Stuy',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/1413-fulton-street'}
# {'address': '252 Atlantic Avenue',
#  'city': 'Brooklyn',
#  'phone': '(347) 991-8701',
#  'status': 3,
#  'title': 'Boerum Hill',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/252-atlantic-avenue'}
# {'address': '9029 Flatlands Avenue',
#  'city': 'Brooklyn',
#  'phone': '(718) 581-5901',
#  'status': 3,
#  'title': 'Canarsie',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/9029-flatlands-avenue'}
# {'address': '2857 W. 8th Street',
#  'city': 'Brooklyn',
#  'phone': '(929) 477-8801',
#  'status': 3,
#  'title': 'Coney Island',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/2857-w.-8th-street'}
# {'address': '399 Knickerbocker Avenue',
#  'city': 'Brooklyn',
#  'phone': '(347) 991-8706',
#  'status': 3,
#  'title': 'Bushwick',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/399-knickerbocker-avenue'}
# {'address': '227 Fourth Avenue',
#  'city': 'Brooklyn',
#  'phone': '(718) 924-2299',
#  'status': 3,
#  'title': 'Park Slope',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/227-fourth-avenue'}
# {'address': '287 Broadway',
#  'city': 'Brooklyn',
#  'phone': '(718) 971-1592',
#  'status': 3,
#  'title': 'Williamsburg',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/287-broadway'}
# {'address': '5109 Fourth Avenue',
#  'city': 'Brooklyn',
#  'phone': '(347) 775-2635',
#  'status': 3,
#  'title': 'Sunset Park',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/5109-fourth-avenue'}
# {'address': '81-83 East 98th Street',
#  'city': 'Brooklyn',
#  'phone': '(718) 233-6720',
#  'status': 3,
#  'title': 'Brownsville',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/81-83-east-98th-street'}
# {'address': '1134 Fulton St.',
#  'city': 'Brooklyn',
#  'phone': '(929) 480-9166',
#  'status': 3,
#  'title': 'Clinton Hill',
#  'url': 'https://locations.blinkfitness.com/ny/brooklyn/1134-fulton-st.'}
# {'address': '450 Main Street',
#  'city': 'Farmingdale',
#  'phone': '(516) 531-6614',
#  'status': 3,
#  'title': 'Farmingdale',
#  'url': 'https://locations.blinkfitness.com/ny/farmingdale/450-main-street'}
# {'address': '358 N. Broadway Mall',
#  'city': 'Hicksville',
#  'phone': '(516) 595-8431',
#  'status': 3,
#  'title': 'Hicksville',
#  'url': 'https://locations.blinkfitness.com/ny/hicksville/358-n.-broadway-mall'}
# {'address': '1790 Veterans Memorial Highway',
#  'city': 'Islandia',
#  'phone': '(631) 784-4333',
#  'status': 3,
#  'title': 'Islandia',
#  'url': 'https://locations.blinkfitness.com/ny/islandia/1790-veterans-memorial-highway'}
# {'address': '78-14 Roosevelt Avenue',
#  'city': 'Jackson Heights',
#  'phone': '(646) 517-6365',
#  'status': 3,
#  'title': 'Jackson Heights',
#  'url': 'https://locations.blinkfitness.com/ny/jackson-heights/78-14-roosevelt-avenue'}
# {'address': '600 North Wellwood Avenue',
#  'city': 'Lindenhurst',
#  'phone': '(631) 429-1030',
#  'status': 3,
#  'title': 'Lindenhurst',
#  'url': 'https://locations.blinkfitness.com/ny/lindenhurst/600-north-wellwood-avenue'}
# {'address': '4979 W. Taft Road',
#  'city': 'Liverpool',
#  'phone': '(315) 928-3830',
#  'status': 3,
#  'title': 'Liverpool',
#  'url': 'https://locations.blinkfitness.com/ny/liverpool/4979-w.-taft-road'}
# {'address': '121 Broadhollow Road',
#  'city': 'Melville',
#  'phone': '(516) 962-5111',
#  'status': 3,
#  'title': 'Melville',
#  'url': 'https://locations.blinkfitness.com/ny/melville/121-broadhollow-road'}
# {'address': '16 E. 4th Street',
#  'city': 'New York',
#  'phone': '(212) 245-6008',
#  'status': 3,
#  'title': 'Noho',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/16-e.-4th-street'}
# {'address': '4200 Broadway',
#  'city': 'New York',
#  'phone': '(347) 338-6465',
#  'status': 3,
#  'title': 'Washington Heights',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/4200-broadway'}
# {'address': '301 W. 125th Street',
#  'city': 'New York',
#  'phone': '(646) 253-9700',
#  'status': 3,
#  'title': '125th',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/301-w.-125th-street'}
# {'address': '600 Third Avenue',
#  'city': 'New York',
#  'phone': '(646) 561-5400',
#  'status': 3,
#  'title': 'Murray Hill',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/600-third-avenue'}
# {'address': '27 W. 116th Street',
#  'city': 'New York',
#  'phone': '(646) 561-5454',
#  'status': 3,
#  'title': '116th',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/27-w.-116th-street'}
# {'address': '308 Eighth Avenue',
#  'city': 'New York',
#  'phone': '(646) 560-4010',
#  'status': 3,
#  'title': 'Chelsea',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/308-eighth-avenue'}
# {'address': '127 W. 30th Street',
#  'city': 'New York',
#  'phone': '(646) 795-2795',
#  'status': 3,
#  'title': 'Penn Station',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/127-w.-30th-street'}
# {'address': '5 Bryant Park',
#  'city': 'New York',
#  'phone': '(646) 795-2681',
#  'status': 3,
#  'title': 'Bryant Park',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/5-bryant-park'}
# {'address': '111 Nassau Street',
#  'city': 'New York',
#  'phone': '(646) 561-5459',
#  'status': 3,
#  'title': 'FiDi',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/111-nassau-street'}
# {'address': '240 E. 54th Street',
#  'city': 'New York',
#  'phone': '(646) 561-5460',
#  'status': 3,
#  'title': '54th',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/240-e.-54th-street'}
# {'address': '125 Park Avenue',
#  'city': 'New York',
#  'phone': '(646) 561-5470',
#  'status': 3,
#  'title': 'Grand Central',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/125-park-avenue'}
# {'address': '98 Avenue A',
#  'city': 'New York',
#  'phone': '(212) 202-3300',
#  'status': 3,
#  'title': 'East Village',
#  'url': 'https://locations.blinkfitness.com/ny/new-york/98-avenue-a'}
# {'address': '163-02 Jamaica Avenue',
#  'city': 'Queens',
#  'phone': '(718) 521-4331',
#  'status': 3,
#  'title': 'Jamaica',
#  'url': 'https://locations.blinkfitness.com/ny/queens/163-02-jamaica-avenue'}
# {'address': '102-16 Liberty Avenue',
#  'city': 'Queens',
#  'phone': '(718) 752-1590',
#  'status': 3,
#  'title': 'Ozone Park',
#  'url': 'https://locations.blinkfitness.com/ny/queens/102-16-liberty-avenue'}
# {'address': '56-02 Roosevelt Avenue',
#  'city': 'Queens',
#  'phone': '(917) 651-0278',
#  'status': 3,
#  'title': 'Woodside',
#  'url': 'https://locations.blinkfitness.com/ny/queens/56-02-roosevelt-avenue'}
# {'address': '108-14 Roosevelt Avenue',
#  'city': 'Queens',
#  'phone': '(917) 962-8829',
#  'status': 3,
#  'title': 'Corona',
#  'url': 'https://locations.blinkfitness.com/ny/queens/108-14-roosevelt-avenue'}
# {'address': '130-20 Farmers Blvd',
#  'city': 'Queens',
#  'phone': '(929) 519-7055',
#  'status': 3,
#  'title': 'Springfield Gardens',
#  'url': 'https://locations.blinkfitness.com/ny/queens/130-20-farmers-blvd'}
# {'address': '220-05 Hillside Avenue',
#  'city': 'Queens',
#  'phone': '(917) 970-3011',
#  'status': 3,
#  'title': 'Queens Village',
#  'url': 'https://locations.blinkfitness.com/ny/queens/220-05-hillside-avenue'}
# {'address': '55-27 Myrtle Avenue',
#  'city': 'Ridgewood',
#  'phone': '(718) 701-6195',
#  'status': 3,
#  'title': 'Ridgewood',
#  'url': 'https://locations.blinkfitness.com/ny/ridgewood/55-27-myrtle-avenue'}
# {'address': '2833 W Ridge Rd',
#  'city': 'Rochester',
#  'phone': '(585) 532-5650',
#  'status': 3,
#  'title': 'Greece',
#  'url': 'https://locations.blinkfitness.com/ny/rochester/2833-w-ridge-rd'}
# {'address': '4722 Onondaga Blvd',
#  'city': 'Syracuse',
#  'phone': '(315) 800-5195',
#  'status': 3,
#  'title': 'Onondaga',
#  'url': 'https://locations.blinkfitness.com/ny/syracuse/4722-onondaga-blvd'}
# {'address': '14 Brooklyn Avenue',
#  'city': 'Valley Stream',
#  'phone': '(516) 206-1990',
#  'status': 3,
#  'title': 'Valley Stream',
#  'url': 'https://locations.blinkfitness.com/ny/valley-stream/14-brooklyn-avenue'}
# {'address': '175 Sunrise Highway',
#  'city': 'West Islip',
#  'phone': '(631) 392-2233',
#  'status': 3,
#  'title': 'West Islip',
#  'url': 'https://locations.blinkfitness.com/ny/west-islip/175-sunrise-highway'}
# {'address': '100 Main Street',
#  'city': 'White Plains',
#  'phone': '(914) 539-8800',
#  'status': 3,
#  'title': 'White Plains',
#  'url': 'https://locations.blinkfitness.com/ny/white-plains/100-main-street'}
# {'address': '8000 Mall Walk',
#  'city': 'Yonkers',
#  'phone': '(914) 375-3900',
#  'status': 3,
#  'title': 'Yonkers',
#  'url': 'https://locations.blinkfitness.com/ny/yonkers/8000-mall-walk'}
# {'address': '8914 Frankford Avenue',
#  'city': 'Philadelphia',
#  'phone': '(215) 383-2536',
#  'status': 0,
#  'title': 'Academy Road',
#  'url': 'https://locations.blinkfitness.com/pa/philadelphia/8914-frankford-avenue'}
# {'address': '5597 Tulip Street',
#  'city': 'Philadelphia',
#  'phone': '(215) 709-2010',
#  'status': 0,
#  'title': 'Wissinoming',
#  'url': 'https://locations.blinkfitness.com/pa/philadelphia/5597-tulip-street'}
# {'address': '330 W. Oregon Avenue',
#  'city': 'Philadelphia',
#  'phone': '(215) 383-2540',
#  'status': 0,
#  'title': 'South Philly',
#  'url': 'https://locations.blinkfitness.com/pa/philadelphia/330-w.-oregon-avenue'}
# {'address': '615 Harwood Rd',
#  'city': 'Bedford',
#  'phone': '(817) 391-8083',
#  'status': 3,
#  'title': 'Bedford',
#  'url': 'https://locations.blinkfitness.com/tx/bedford/615-harwood-rd'}
# {'address': '7410 N Beach St',
#  'city': 'Fort Worth',
#  'phone': '(817) 428-2030',
#  'status': 3,
#  'title': 'Beach Street',
#  'url': 'https://locations.blinkfitness.com/tx/fort-worth/7410-n-beach-st'}
# {'address': '4400 North Freeway',
#  'city': 'Houston',
#  'phone': '(281) 936-0098',
#  'status': 1,
#  'title': 'Northline',
#  'url': 'https://locations.blinkfitness.com/tx/houston/4400-north-freeway'}
# {'address': '7840 Long Point Rd',
#  'city': 'Houston',
#  'phone': '(346) 355-9371',
#  'status': 3,
#  'title': 'Spring Branch',
#  'url': 'https://locations.blinkfitness.com/tx/houston/7840-long-point-rd'}
# {'address': '11145 Westheimer Road',
#  'city': 'Houston',
#  'phone': '(346) 355-9375',
#  'status': 3,
#  'title': 'Westchase',
#  'url': 'https://locations.blinkfitness.com/tx/houston/11145-westheimer-road'}
# {'address': '8201 Broadway Street',
#  'city': 'Houston',
#  'phone': '(346) 285-7862',
#  'status': 3,
#  'title': 'Hobby',
#  'url': 'https://locations.blinkfitness.com/tx/houston/8201-broadway-street'}
# {'address': '3529 Heritage Trace Pkwy',
#  'city': 'Keller',
#  'phone': '(682) 647-5114',
#  'status': 3,
#  'title': 'Keller',
#  'url': 'https://locations.blinkfitness.com/tx/keller/3529-heritage-trace-pkwy'}
# {'address': '7901 Mid Cities Blvd',
#  'city': 'North Richland Hills',
#  'phone': '(817) 893-6890',
#  'status': 3,
#  'title': 'North Richland Hills',
#  'url': 'https://locations.blinkfitness.com/tx/north-richland-hills/7901-mid-cities-blvd'}
# {'branch_address': '4239 Holland Road\nVirginia Beach, VA 23462',
#  'branch_city': 'Virginia Beach',
#  'branch_phone': '(757) 432-3584',
#  'branch_state': 'Virginia',
#  'branch_title': 'Virginia Beach',
#  'branch_url': 'https://locations.blinkfitness.com/va/virginia-beach/4239-holland-road'}
